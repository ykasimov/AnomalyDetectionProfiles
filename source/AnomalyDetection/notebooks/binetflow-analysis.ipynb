# %%
import os
import pandas as pd

# %%
df = pd.read_csv(os.path.expanduser('~/Documents/Aposemat/CTU-Honeypot-Capture-2-2/2018-05-16-17-33-41-192.168.100.109.binetflow'))

# %%
df.head()
# Out:
#                     StartTime          Dur Proto          SrcAddr  Sport  \
# 0  2018/05/16 17:33:52.950173   981.179749   udp  192.168.100.109  28447
# 1  2018/05/16 17:33:57.953844  3560.818604   arp  192.168.100.109    NaN
# 2  2018/05/16 17:34:19.889665     0.000491   udp  192.168.100.109  60158
# 3  2018/05/16 17:34:19.890905     0.003997   tcp  192.168.100.109  35524
# 4  2018/05/16 17:34:24.538033     6.020588   udp  192.168.100.109  40184
#
#      Dir          DstAddr Dport    State  sTos  dTos  TotPkts  TotBytes  \
# 0     ->   122.248.252.67  9765      INT   0.0   NaN       50      3870
# 1    who    192.168.100.1   NaN      CON   NaN   NaN      108      6480
# 2    <->    192.168.100.1    53      CON   0.0   0.0        2       164
# 3     ->   172.217.23.196    80  FSA_FSA   0.0   0.0        6       412
# 4     ->  239.255.255.250  1900      INT   0.0   NaN        4       671
#
#    SrcBytes  SrcPkts  Label
# 0      3870       50    NaN
# 1      3240       54    NaN
# ...

# %%
df[df['Proto']=='udp'].groupby(['DstAddr', 'Dport']).size()
# Out:
# DstAddr          Dport
# 122.248.234.231  8760       75
# 122.248.252.67   8760       75
#                  9765       76
# 147.251.48.140   123         1
# 192.168.100.1    53       1586
# 239.255.255.250  1900      698
# 255.255.255.255  11651       1
#                  12117       1
#                  12772       1
#                  13922       1
#                  14040       1
#                  14927       1
#                  15306       1
#                  15528       1
#                  15833       1
#                  16635       1
#                  17167       1
#                  17319       1
#                  17340       1
#                  18376       1
#                  19689       1
#                  20239       1
#                  21617       1
#                  22825       1
#                  23121       1
#                  23330       1
#                  2336        1
#                  25744       1
#                  25935       1
# ...
